# %% [markdown]
# # Prepare trainig data by combining historical data and new data

# %% [markdown]
# ## Load recently obtained data

# %%
import numpy as np 
import pandas as pd 

path_ls = []
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        path = os.path.join(dirname, filename)
        print(path)
        path_ls.append(path)
# Out:
# /kaggle/input/2025-03-27-6/2025-03-28 06_16_16.546768_historical.csv
# /kaggle/input/new-sentiments/2025-03-19.csv
# /kaggle/input/new-sentiments/2025-03-25.csv
# /kaggle/input/new-sentiments/2025-03-21.csv
# /kaggle/input/new-sentiments/2025-03-27.csv
# /kaggle/input/new-sentiments/2025-03-17.csv

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
path_ls = path_ls[1:-1]
dates = [p[-14:-4] for p in path_ls]
dates
# Out:
# ['2025-03-19', '2025-03-25', '2025-03-21', '2025-03-27']

# %%
dates.sort()
print(dates)
# Out:
# ['2025-03-19', '2025-03-21', '2025-03-25', '2025-03-27']

# %% [markdown]
# ## Combine daily sentiment data

# %%
base_path = "/input_path/2025-03-17.csv"
base_df = pd.read_csv(base_path)
def combine_sentiment(base_df, dates):
    for date in dates:
        path = "/input_path/" + date + ".csv"
        new_df = pd.read_csv(path)
        entries_to_add = new_df[new_df['Date'] >  base_df['Date'].max()]
        base_df = pd.concat([base_df, entries_to_add], ignore_index=True)

    return base_df
        
new_sentiments_df = combine_sentiment(base_df, dates)
new_sentiments_df = new_sentiments_df[['Date', 'Symbol', 'sentiment']]
new_sentiments_df = new_sentiments_df.dropna()
new_sentiments_df.head()
# Out:
#           Date Symbol  sentiment
# 37  2025-03-12   ABBV        0.0
# 38  2025-03-13   ABBV        0.0
# 39  2025-03-14   ABBV        0.0
# 59  2025-03-14    ABT       -0.5
# 77  2025-03-12    ACN       -0.5

# %% [markdown]
# ## Merge with historic data

# %%
hist_path = '/kaggle/input/2025-03-27-6/2025-03-28 06_16_16.546768_historical.csv'
historic_df = pd.read_csv(hist_path)
historic_df.tail(5)
# Out:
#         Unnamed: 0        Date        Open        High         Low  \
# 272149      272149  2025-03-21  115.500000  115.989998  114.349998
# 272150      272150  2025-03-24  115.680000  116.910004  115.580002
# 272151      272151  2025-03-25  116.430000  117.639999  115.959999
# 272152      272152  2025-03-26  117.680000  119.180000  117.680000
# 272153      272153  2025-03-27  118.099998  119.070000  117.260002
#
#              Close    Volume  Dividends  Stock Splits  month  ...  sentiment  \
# 272149  115.500000  41102800        0.0           0.0      3  ...        NaN
# 272150  115.800003  14207500        0.0           0.0      3  ...        NaN
# 272151  116.589996  12081800        0.0           0.0      3  ...        NaN
# 272152  118.269997  14112800        0.0           0.0      3  ...        NaN
# 272153  117.889999  12734100        0.0           0.0      3  ...        NaN
#
#               RSI       MA_20       MA_50      MA_200  log_return     RV_20  \
# 272149  69.664613  110.709501  109.526608  112.497300   -0.003457  0.256330
# 272150  70.900797  110.936001  109.722967  112.526918    0.002594  0.256078
# 272151  80.216766  111.279001  109.942858  112.558292    0.006799  0.249460
# 272152  79.665701  111.719501  110.141835  112.593921    0.014307  0.251652
# 272153  76.196086  112.106501  110.324690  112.633599   -0.003218  0.252702
#
#            RV_50  symbol  time_idx
# 272149  0.239104     XOM      2511
# 272150  0.235424     XOM      2512
# 272151  0.235355     XOM      2513
# 272152  0.230910     XOM      2514
# 272153  0.231122     XOM      2515
#
# [5 rows x 31 columns]

# %%
historic_df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume',
#        'Dividends', 'Stock Splits', 'month', 'day', 'day_of_week', 'NASDAQ',
#        'SNP', 'DJI', 'RUT', 'VIX', 'XLK', 'XLE', 'XLF', 'XLV', 'sentiment',
#        'RSI', 'MA_20', 'MA_50', 'MA_200', 'log_return', 'RV_20', 'RV_50',
#        'symbol', 'time_idx'],
#       dtype='object')

# %%
def combine_historic_and_new_data(historic_df, new_df):

    # Merge A with B on Date and symbol
    merged = pd.merge(
        historic_df,
        new_df,
        on=['Date', 'symbol'],
        how='left',
        suffixes=('_A', '_B')
    )

    # Choose sentiment: take sentiment_A unless it's missing, then use sentiment_B
    merged['sentiment'] = merged['sentiment_A'].combine_first(merged['sentiment_B'])
    return merged

# %%
combined_df = combine_historic_and_new_data(historic_df, new_sentiments_df.rename(columns={'Symbol': 'symbol'}))

# %%
combined_df.sample(20)
# Out:
#         Unnamed: 0        Date        Open        High         Low  \
# 111645      111645  2021-03-04   52.908170   54.374098   52.680698
# 26442        26442  2020-09-15  156.807999  158.751007  155.445999
# 194891      194891  2018-11-21    3.830203    3.847047    3.557466
# 181305      181305  2018-12-24   57.313980   57.606355   56.018032
# 153685      153685  2022-07-12  322.146089  324.088718  315.664105
# 251339      251339  2021-10-05  189.439116  195.755905  189.439116
# 90010        90010  2018-03-28   95.583443   96.140615   94.286584
# 99239        99239  2024-01-25   93.073296   94.099512   92.369601
# 151448      151448  2016-04-01   61.075152   62.866461   61.015442
# 237309      237309  2021-07-30  529.933310  538.265350  526.455827
# 171074      171074  2021-11-01   56.890442   57.653894   56.620990
# 117538      117538  2024-08-01  171.364034  175.050779  169.899298
# 182757      182757  2023-10-05   98.076759   99.370267   98.057592
# 116308      116308  2019-09-11   59.886851   60.841827   59.826635
# 239432      239432  2019-05-22   74.800359   75.426221   74.458092
# 77234        77234  2023-08-02   50.024132   50.721299   49.966829
# 167269      167269  2020-01-08  100.051360  101.422285   99.999302
# 175219      175219  2017-10-25  149.794659  151.662229  149.112641
# 161484      161484  2023-07-17  398.472530  400.504783  397.649694
# 59133        59133  2021-02-02   71.780830   72.600144   71.516829
#
#              Close      Volume  Dividends  Stock Splits  month  ...  \
# 111645   53.270439    15847200        0.0           0.0      3  ...
# 26442   157.806503    80430000        0.0           0.0      9  ...
# 194891    3.584715  1025496000        0.0           0.0     11  ...
# 181305   56.223488    11565833        0.0           0.0     12  ...
# 153685  315.888641     2058200        0.0           0.0      7  ...
# 251339  193.908890     4177300        0.0           0.0     10  ...
# 90010    94.661232     9099700        0.0           0.0      3  ...
# 99239    94.060417     2344500        0.0           0.0      1  ...
# 151448   62.627621     4083600        0.0           0.0      4  ...
# 237309  535.005859     1412800        0.0           0.0      7  ...
# 171074   57.617966     3966100        0.0           0.0     11  ...
# 117538  171.832352    17177800        0.0           0.0      8  ...
# 182757   99.264870     6449100        0.0           0.0     10  ...
# 116308   60.720898    26140000        0.0           0.0      9  ...
# 239432   74.663452     3287300        0.0           0.0      5  ...
# 77234    50.215137    17693700        0.0           0.0      8  ...
# 167269  101.083893     5482800        0.0           0.0      1  ...
# 175219  151.496506     4920942        0.0           0.0     10  ...
# 161484  398.720367     2344500        0.0           0.0      7  ...
# 59133    71.780830     5018800        0.0           0.0      2  ...
#
#              MA_20       MA_50      MA_200  log_return     RV_20     RV_50  \
# 111645   54.647907   53.409452   55.107781    0.007620  0.245043  0.270515
# 26442   165.414223  159.255148  124.129830    0.016987  0.385770  0.375195
# 194891    4.803533    5.765453    6.033791   -0.029751  1.074092  0.788086
# 181305   59.491340   59.724317   55.440907   -0.024298  0.172480  0.150961
# 153685  306.704544  298.019590  263.365708   -0.022852  0.279580  0.308097
# 251339  187.954119  197.010518  197.516079    0.021470  0.250899  0.182007
# 90010    98.345754  101.251201   99.494550   -0.008287  0.168346  0.230616
# 99239    93.083068   90.413223   88.174475    0.019410  0.166959  0.185595
# 151448   60.912247   61.854988   67.668414    0.019391  0.285438  0.232156
# 237309  517.146840  487.596917  473.776197    0.011623  0.142494  0.220356
# 171074   58.368391   56.501534   54.066173    0.021269  0.244718  0.243571
# 117538  180.465830  179.269109  153.667762   -0.004051  0.292758  0.231323
# 182757  101.342536  102.085528  103.789682    0.013899  0.122330  0.173665
# 116308   58.989971   58.343200   56.471435    0.011681  0.237256  0.307938
# 239432   73.456711   71.882080   68.318331    0.000000  0.226999  0.173158
# 77234    49.663608   48.536923   45.821517   -0.001520  0.204242  0.167662
# 167269   98.925097   97.896412   94.067468    0.000000  0.089157  0.089147
# 175219  140.239748  135.367869  128.949717    0.012830  0.206445  0.156863
# 161484  384.896288  377.933348  352.627741   -0.000770  0.127490  0.183404
# 59133    73.037572   75.414728   69.755459    0.004194  0.150838  0.122809
#
#         symbol  time_idx  sentiment_B  sentiment
# 111645    GILD      1494          NaN        NaN
# 26442     AMZN      1377          NaN        NaN
# 194891    NVDA       922          NaN  -0.200000
# 181305     MRK       943          NaN   0.000000
# 153685     LLY      1835          NaN        NaN
# 251339     UNP      1643          NaN        NaN
# 90010      DIS       756          NaN        NaN
# 99239      EMR      2222          NaN        NaN
# 151448     LLY       255          NaN        NaN
# 237309     TMO      1597          NaN        NaN
# 171074     MET      1662          NaN        NaN
# 117538    GOOG      2352          NaN        NaN
# 182757     MRK      2146          NaN   0.000000
# 116308    GOOG      1122          NaN        NaN
# 239432    TMUS      1045          NaN  -0.500000
# 77234     CSCO      2101          NaN        NaN
# 167269     MDT      1204          NaN   0.000000
# 175219     MMM       651          NaN   0.384615
# 161484      MA      2089          NaN        NaN
# 59133       CL      1473          NaN        NaN
#
# [20 rows x 33 columns]

# %% [markdown]
# ## Impute Missing Sentiments with ARIMA model

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Train an ARIMA model to predict missing values
def impute_arima(df, column_name):
    # Make sure your column does not have NaNs initially
    series = df[column_name]

    # Fit ARIMA model to the non-missing data
    model = ARIMA(series, order=(5, 1, 0))  # You can experiment with the order
    model_fit = model.fit()

    # Predict the missing values using the fitted ARIMA model
    predictions = model_fit.predict(start=0, end=len(series)-1, typ='levels')

    # Fill NaN values with predicted values
    df[column_name].fillna(pd.Series(predictions, index=df.index), inplace=True)

    return df

# %%
combined_df = impute_arima(combined_df, 'sentiment')

# %%
combined_df.sample(100)
# Out:
#         Unnamed: 0        Date        Open        High         Low  \
# 24712        24712  2023-12-07  203.060080  203.491916  201.764559
# 216175      216175  2019-01-02   56.856821   58.581558   56.359406
# 133326      133326  2023-10-30   34.886519   35.368457   34.345564
# 165775      165775  2016-09-07   70.225109   70.394831   69.497721
# 255727      255727  2018-04-19   38.319258   38.924703   38.303930
# ...            ...         ...         ...         ...         ...
# 137371      137371  2016-09-27   93.709891   94.366867   93.179564
# 142551      142551  2023-06-22  136.327745  136.605562  133.108988
# 105830      105830  2018-08-10  165.034716  165.369280  163.559199
# 121148      121148  2017-04-03  193.786709  193.870969  190.054214
# 250702      250702  2019-05-07  153.250316  154.021656  151.050262
#
#              Close    Volume  Dividends  Stock Splits  month  ...       MA_20  \
# 24712   202.215591   1964500        0.0           0.0     12  ...  192.021806
# 216175   58.554527   9361752        0.0           0.0      1  ...   61.529831
# 133326   35.102898  36656300        0.0           0.0     10  ...   34.903732
# 165775   69.627037   4756500        0.0           0.0      9  ...   70.170557
# 255727   38.855728  10690900        0.0           0.0      4  ...   38.884088
# ...            ...       ...        ...           ...    ...  ...         ...
# 137371   94.366867   5349500        0.0           0.0      9  ...   93.772433
# 142551  133.712509  10075200        0.0           0.0      6  ...  133.890681
# 105830  164.545731    954300        0.0           0.0      8  ...  168.657882
# 121148  192.910461   3735600        0.0           0.0      4  ...  201.125343
# 250702  153.171432   4547300        0.0           0.0      5  ...  152.074490
#
#              MA_50      MA_200  log_return     RV_20     RV_50  symbol  \
# 24712   173.492307  178.567039   -0.000190  0.229097  0.315198     AMT
# 216175   65.518635   68.231328    0.016948  0.314171  0.310670     RTX
# 133326   34.998055   31.392888    0.004212  0.433922  0.374445    INTC
# 165775   70.416977   67.329331    0.000000  0.110182  0.083259     MDT
# 255727   39.600156   41.073771    0.013903  0.144244  0.203503     USB
# ...            ...         ...         ...       ...       ...     ...
# 137371   94.266142   92.007045    0.012152  0.093410  0.083826     JNJ
# 142551  132.440900  124.871239   -0.019440  0.152327  0.242842     JPM
# 105830  165.163027  177.086267   -0.003955  0.200990  0.156410      GD
# 121148  203.216596  167.154995   -0.003314  0.181633  0.197600      GS
# 250702  148.072224  136.159127   -0.013697  0.215417  0.181977     UNP
#
#         time_idx  sentiment_B  sentiment
# 24712       2190          NaN  -0.500000
# 216175       948          NaN   0.260521
# 133326      2163          NaN   0.368597
# 165775       365          NaN   0.000000
# 255727       771          NaN   0.600000
# ...          ...          ...        ...
# 137371       379          NaN   0.160258
# 142551      2073          NaN  -0.775803
# 105830       850          NaN   0.981159
# 121148       508          NaN   0.056101
# 250702      1034          NaN   0.313443
#
# [100 rows x 33 columns]

# %%
combined_df = combined_df.drop(columns=['sentiment_A', 'sentiment_B'])
combined_df = combined_df.dropna()
len(combined_df)
# Out:
# 252847

# %% [markdown]
# ## Make sure no NaN values left in dataset

# %%
null_counts = combined_df.isna().sum()

# Display the result
print(null_counts)
print(len(merged_df))
combined_df.sample(10)
# Out:
# Unnamed: 0      0
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# month           0
# day             0
# day_of_week     0
# NASDAQ          0
# SNP             0
# DJI             0
# RUT             0
# VIX             0
# XLK             0
# XLE             0
# XLF             0
# XLV             0
# RSI             0
# MA_20           0
# MA_50           0
# MA_200          0
# log_return      0
# RV_20           0
# RV_50           0
# symbol          0
# time_idx        0
# sentiment       0
# dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-f6fd34546658> in <cell line: 5>()
#       3 # Display the result
#       4 print(null_counts)
# ----> 5 print(len(merged_df))
#       6 merged_df.sample(10)
#
# NameError: name 'merged_df' is not defined

# %% [markdown]
# ## Write Out Training Dataset

# %%
from datetime import datetime
combined_df.to_csv(f"{datetime.today()}_training.csv")
